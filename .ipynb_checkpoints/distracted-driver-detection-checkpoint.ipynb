# %% [markdown]
# # Kaggle challenge - State Farm Distracted Driver detection #
# Nepp & Dumhart
#
#
# ## Dataset ##
#
# - 102k files ( labeled images of drivers )

# %%
import cv2
import numpy as np
from PIL import Image
from IPython.display import display


def display_array(array):
    if len(array.shape) > 2: # Check whether image is colored
        array = cv2.cvtColor(array.astype("uint8"), cv2.COLOR_BGR2RGB) # Swap BGR to RGB
    pil_img = Image.fromarray(array)
    display(pil_img)

# %% [markdown]
# ---
#
# ### Preprocessing : ###

# %%
def normalize_image(image) :
    image = image * (255.0/image.max())
    #image /= 255.0
    return image
 
def line_detection( image ) :
        # Creating a custom line filter :
    line_filter = np.array([[-1, -2, -1], 
                            [ 0,  0,  0], 
                            [ 1,  2,  1]])
    stage_1 = ((cv2.filter2D(image, -1, line_filter) + cv2.filter2D(image, -1, line_filter.T))/2).astype(np.uint8)
    
    # New mirrored line filter :
    line_filter = np.array([[  1,   2,   1], 
                            [  0,   0,   0], 
                            [ -1,  -2,  -1]])
    stage_2 = ((cv2.filter2D(image, -1, line_filter) + cv2.filter2D(image, -1, line_filter.T))/2).astype(np.uint8)
    
    return np.maximum(stage_1,stage_2).astype(np.uint8)

def greyed_blured_and_line_detection( image, advanced=False ) :
    # Remove color :
    image = cv2.cvtColor(image, cv2.COLOR_BGR2GRAY)
    # Blur :
    blured = cv2.GaussianBlur(image,(5, 5), 0)
    
    if not advanced :
        return line_detection(blured)
    else :
        image = line_detection( image )
        blured = line_detection( blured )
        very_blured = cv2.GaussianBlur(image,(11, 11), 0)
        return  np.maximum(
                line_detection(very_blured), 
                np.maximum(image,blured).astype(np.uint8)).astype(np.uint8)

        #np.maximum(image,blured).astype(np.uint8)
    
   
def preprocess_image(img, advanced=False, image_shape=None, flatten=True) :
    img = greyed_blured_and_line_detection(img, advanced=advanced)
    img = normalize_image(img)
    #print('After norm :',img)
    if image_shape is not None : img = cv2.resize(img,(image_shape[1],image_shape[0]))
    #print('After resize :', img)
    if flatten : img = img.flatten()
    
    return img


test_img = cv2.imread("data/imgs/test/img_2.jpg")
test_img = preprocess_image(test_img, image_shape=(128, 96), flatten=False)
print(test_img.shape)

# Let's test the preprocessing suite first :  
test_img = cv2.imread("data/imgs/test/img_2.jpg")
test_img = preprocess_image(test_img)
assert test_img.shape == (307200,)
assert str(test_img) == '[ 0.          2.00787402  4.01574803 ... 18.07086614  4.01574803\n  0.        ]'
test_img = cv2.imread("data/imgs/test/img_2.jpg")
test_img = preprocess_image(test_img, flatten=False)
assert test_img.shape == (480, 640) 
del test_img
#------------------------------------------------------------------------------------------------------
    
print(cv2.imread("data/imgs/test/img_2.jpg").shape)
    
# Converting to grayscale
display_array(
    cv2.resize(
    greyed_blured_and_line_detection( 
        cv2.imread("data/imgs/test/img_2.jpg"), advanced=False
    ),(128, 96))
)
display_array(
    cv2.resize(
    greyed_blured_and_line_detection( 
        cv2.imread("data/imgs/test/img_2.jpg"), advanced=True
    ),(128, 96))
)
display_array(
    greyed_blured_and_line_detection( 
        cv2.imread("data/imgs/test/img_2.jpg"), advanced=True
    )
)
# Out:
# (128, 96)
# (480, 640, 3)
# <PIL.Image.Image image mode=L size=128x96 at 0x262965B3B50>
# <PIL.Image.Image image mode=L size=128x96 at 0x262AD506DC0>
# <PIL.Image.Image image mode=L size=640x480 at 0x262AD515A00>

# %% [markdown]
# ---
#
# ### Batch Reading : ##

# %%
import os, os.path
import pandas as pd

# This method returns the number of files at a given relative path.
def files_in_dir(file_path) :
    # simple version for working with CWD 
    # https://stackoverflow.com/questions/2632205/how-to-count-the-number-of-files-in-a-directory-using-python
    return len([name for name in os.listdir(file_path)]) 

assert files_in_dir("./data/imgs/test/") == 79726

# This method generates a ditionary of class names and the number of instances.
def create_class_data_map(path) :
    
    directories = os.listdir(path)
    
    class_data_map = dict()
    
    for c in directories : 
        class_data_map[c] = files_in_dir(path+"/"+c)
        
    return class_data_map
    
# Testing the above :  
assert str(create_class_data_map("./data/imgs/")) == "{'test': 79726, 'train': 10}"

# This method is currently not used. It takes percentage chunks from a provided
# "class_data_map" generated by the method above.
def create_class_data_picks(class_data_map, percentage) :
    
    if percentage is None : return class_data_map
    
    assert percentage <= 1 and percentage >= 0
    
    # https://w3resource.com/python-exercises/dictionary/python-data-type-dictionary-exercise-15.php
    key_min = min(class_data_map.keys(), key=(lambda k: class_data_map[k]))
    print('Min Value: ',class_data_map[key_min])
    
    temp = dict()
    for c, d in class_data_map.items(): temp[c] = int(class_data_map[key_min] * percentage)
        
    return temp
        
    
def load_batch( 
    path, 
    class_picks, 
    size, 
    index, 
    do_label_index_encoding=False, 
    advanced_preprocessing=False,
    image_shape=None,
    flatten=True
) : 
    
    batch = []
    labels = []
    class_list = list(class_picks.keys())
    
    read_checker = {c:-size*index for c in class_list}
    
    imgs_list = pd.read_csv("data/driver_imgs_list.csv")
    
    for index, row in imgs_list.iterrows():
        
        c = row['classname']
        
        if read_checker[c] < 0 : read_checker[c] += 1
        elif read_checker[c] < size :
            #print('Loading class : "',c,'"; Already read :', read_checker[c])
            read_checker[c] += 1
            name = row['img']
            img = cv2.imread(path+"/"+c+"/"+name)
            img = preprocess_image(
                img, 
                advanced=advanced_preprocessing,
                image_shape=image_shape,
                flatten=flatten
            ) 
            label = None
            label_index = class_list.index(c)
            if do_label_index_encoding :
                label = label_index
            else :
                label = [0]*len(class_list)
                label[label_index] = 1
                label = np.array(label)
            #print('Appending : B->',img.shape,'; L->',label.shape)
            batch.append(img)
            labels.append(label)
                 
    batch = np.stack(batch)
    labels = np.stack(labels)
    return batch, labels
    
     
b, l = load_batch(
    "data/imgs/train", 
    create_class_data_map("data/imgs/train"),
    size=6, index=0
)
    
assert b.shape == (60, 307200)
assert l.shape == (60, 10)
    
b, l = load_batch(
    "data/imgs/train", 
    create_class_data_map("data/imgs/train"),
    size=6, index=0, do_label_index_encoding=True
)

assert b.shape == (60, 307200)
assert l.shape == (60,)
    
b, l = load_batch(
    "data/imgs/train", 
    create_class_data_map("data/imgs/train"),
    size=6, index=0, do_label_index_encoding=True, flatten=False
)
 
assert b.shape == (60, 480, 640)
assert l.shape == (60,)

b, l = load_batch(
    "data/imgs/train", 
    create_class_data_map("data/imgs/train"),
    size=6, index=0, do_label_index_encoding=True, flatten=False,
    image_shape=(128, 96)
)
 
assert b.shape == (60, 128, 96)
assert l.shape == (60,)
    
del b, l

# %%
import tensorflow as tf

import keras
from keras.utils.generic_utils import get_custom_objects
from keras import backend as K
from keras.layers import Activation

def mish(x): return x * (K.tanh(K.softplus(x)))
get_custom_objects().update({'mish': Activation(mish)})

def exec_trial(settings) :
    
    print('Starting trial with the following parameters : \n', settings)
     
    do_conv = settings['convos'] != None
    flatten = not do_conv
    
    actifuns = settings['actifuns']
    layer_sizes = settings['layer_sizes']
    batch_size = settings['batch_size'] #:= 50
    

    # Loading (and preprocessing) data :
    train_batch, train_labels = load_batch(
        "data/imgs/train", 
        create_class_data_map("data/imgs/train"), 
        size=batch_size, index=0, 
        do_label_index_encoding=True,
        advanced_preprocessing=True,
        image_shape=(128, 96),#(256, 192) #640 * 480
        flatten=flatten
    )
    
    print('Input shape :', train_batch.shape, '; flatten : ', flatten, '; do_conv :', do_conv)
    
    if do_conv : 
        train_batch = train_batch.reshape(list(train_batch.shape) + [1]) 
        
    print('Input shape :', train_batch.shape)
        
    batch_size = train_batch.shape[0]
    input_dimension = train_batch.shape[1]
    input_shape = train_batch.shape
    output_dimension = train_labels.shape[0]
 
    model = keras.Sequential()
    model.add(Activation(mish, name='mish'))
    #---------------------------------------
    hidden_acti = 'mish'

    # CONVOLUTION ... WIP
    if do_conv :
        first_iter_done = False
        for convo in settings['convos'] : 
            value = convo['value']
            if convo['type'] is 'conv2d' : 
                if first_iter_done :
                    model.add(
                        keras.layers.Conv2D(
                            value['filters'], 
                            value['kernel_size'],  
                            activation=value['activation'],  
                            padding=value['padding']
                        )
                    )
                else :
                    model.add(
                        keras.layers.Conv2D(
                            value['filters'], 
                            value['kernel_size'], 
                            input_shape=(128, 96, 1),
                            activation=value['activation'],  
                            padding=value['padding']
                        )
                    )
            elif convo['type'] is 'maxpool' : 
                model.add(keras.layers.MaxPooling2D(pool_size=convo['value']['pool_size']))
            elif convo['type'] is 'avgpool' :
                model.add(keras.layers.AveragePooling2D(pool_size=convo['value']['pool_size']))
            else : print('Invalid configuration!!! Convolution type "', convo['type'],'" unknown!')
            first_iter_done = True
        
        model.add(keras.layers.Flatten())
        start = 0
    else :  
        model.add(keras.layers.Dense(layer_sizes[0], input_dim=input_dimension, activation=actifuns[0]))
        start = 1
    
    for i in range(start, len(layer_sizes)) :
        print('Adding layer', i, 'with size ', layer_sizes[i], 'and activation', actifuns[i])
        model.add(keras.layers.Dense(layer_sizes[i], activation=actifuns[i]))

    model.add(keras.layers.Dropout(0.5))
    model.add(keras.layers.Dense(output_dimension, activation="softmax"))

    
    # Create model
    model.compile(
        optimizer=keras.optimizers.Adam(learning_rate=0.01),
        loss="sparse_categorical_crossentropy",
        metrics=["sparse_categorical_accuracy"]
    )

    # Configure stopping criterion via early stopping
    # callback = tf.keras.callbacks.EarlyStopping(monitor="loss", patience=4)

    # Train model
    history_augmented = model.fit(
        train_batch, 
        train_labels,
        validation_split=0.2,
        epochs=100,
        #callbacks=[callback],
        verbose=True
    )

    X_test, y_test = load_batch(
        "data/imgs/train", 
        create_class_data_map("data/imgs/train"), 
        size=batch_size, index=1, do_label_index_encoding=True,
        advanced_preprocessing=True,
        image_shape=(128, 96),#(256, 192) #640 * 480
        flatten=flatten
    )

    test_loss, test_acc = model.evaluate(X_test, y_test)
    print('Done! Test-loss:', test_loss, '; Test-acc', test_acc, ';')
# Out:
# <>:56: SyntaxWarning: "is" with a literal. Did you mean "=="?
# <>:76: SyntaxWarning: "is" with a literal. Did you mean "=="?
# <>:78: SyntaxWarning: "is" with a literal. Did you mean "=="?
# <>:56: SyntaxWarning: "is" with a literal. Did you mean "=="?
# <>:76: SyntaxWarning: "is" with a literal. Did you mean "=="?
# <>:78: SyntaxWarning: "is" with a literal. Did you mean "=="?
# <ipython-input-4-34ba71c13c9e>:56: SyntaxWarning: "is" with a literal. Did you mean "=="?
#   if convo['type'] is 'conv2d' :
# <ipython-input-4-34ba71c13c9e>:76: SyntaxWarning: "is" with a literal. Did you mean "=="?
#   elif convo['type'] is 'maxpool' :
# <ipython-input-4-34ba71c13c9e>:78: SyntaxWarning: "is" with a literal. Did you mean "=="?
#   elif convo['type'] is 'avgpool' :

# %% [markdown]
# ## Let's do some hyperparameter tuning : ##

# %%
trials = [
    {
        'actifuns' : ['mish', 'mish', 'mish', 'mish', 'mish', 'mish'],
        'layer_sizes' : [1024, 512, 256, 64, 64, 64],
        'batch_size' : 50,
        'convos' : None
    },
    {
        'actifuns' : ['mish', 'mish', 'mish', 'mish', 'mish', 'mish'],
        'layer_sizes' : [1024, 512, 256, 64, 64, 64],
        'batch_size' : 50,
        'convos' : [
                   #64, (8,8), input_shape=(128, 96, 1),activation=hidden_acti,  padding="same"
            {
                'type':'conv2d', #128, (8, 8), activation="selu", padding="same"
                'value' : {
                    'filters': 64,
                    "kernel_size": (8,8),
                    "activation" : "relu",
                    "padding": "same"
                }
            },
            {
                'type':'conv2d', #128, (8, 8), activation="selu", padding="same"
                'value' : {
                    'filters': 128,
                    "kernel_size": (8,8),
                    "activation" : "relu",
                    "padding": "same"
                }
            },
            {
                'type':'conv2d', 
                'value' : {
                    'filters': 128,
                    "kernel_size": (8,8),
                    "activation" : "relu",
                    "padding": "same"
                }
            },
            {
                'type':'maxpool', 
                'value' : {
                    'pool_size': (8,8)
                }
            }
            
            
        ]
    }
]
   
for trial in trials : exec_trial(trial)
# Out:
# Starting trial with the following parameters :
#  {'actifuns': ['mish', 'mish', 'mish', 'mish', 'mish', 'mish'], 'layer_sizes': [1024, 512, 256, 64, 64, 64], 'batch_size': 50, 'convos': None}
# Input shape : (500, 12288) ; flatten :  True ; do_conv : False
# Input shape : (500, 12288)
# Adding layer 1 with size  512 and activation mish
# Adding layer 2 with size  256 and activation mish
# Adding layer 3 with size  64 and activation mish
# Adding layer 4 with size  64 and activation mish
# Adding layer 5 with size  64 and activation mish
# Epoch 1/100
# 13/13 [==============================] - 1s 56ms/step - loss: 1605.6974 - sparse_categorical_accuracy: 0.0750 - val_loss: 6.2475 - val_sparse_categorical_accuracy: 0.0000e+00
# Epoch 2/100
# 13/13 [==============================] - 1s 43ms/step - loss: 13.0382 - sparse_categorical_accuracy: 0.1400 - val_loss: 6.2174 - val_sparse_categorical_accuracy: 0.0000e+00
# Epoch 3/100
# 13/13 [==============================] - 1s 43ms/step - loss: 3.5741 - sparse_categorical_accuracy: 0.1175 - val_loss: 11.3424 - val_sparse_categorical_accuracy: 0.0000e+00
# Epoch 4/100
# 13/13 [==============================] - 1s 42ms/step - loss: 2.2819 - sparse_categorical_accuracy: 0.1125 - val_loss: 17.2345 - val_sparse_categorical_accuracy: 0.0000e+00
# Epoch 5/100
# 13/13 [==============================] - 1s 43ms/step - loss: 2.2148 - sparse_categorical_accuracy: 0.1150 - val_loss: 17.4733 - val_sparse_categorical_accuracy: 0.0000e+00
# Epoch 6/100
# 13/13 [==============================] - 1s 44ms/step - loss: 2.1828 - sparse_categorical_accuracy: 0.1300 - val_loss: 16.1513 - val_sparse_categorical_accuracy: 0.0000e+00
# Epoch 7/100
# 13/13 [==============================] - 1s 44ms/step - loss: 2.1020 - sparse_categorical_accuracy: 0.1625 - val_loss: 15.1572 - val_sparse_categorical_accuracy: 0.0000e+00
# Epoch 8/100
# 13/13 [==============================] - 1s 43ms/step - loss: 2.1280 - sparse_categorical_accuracy: 0.1200 - val_loss: 14.4594 - val_sparse_categorical_accuracy: 0.0000e+00
# Epoch 9/100
# 13/13 [==============================] - 1s 43ms/step - loss: 2.1199 - sparse_categorical_accuracy: 0.1300 - val_loss: 13.9624 - val_sparse_categorical_accuracy: 0.0000e+00
# Epoch 10/100
# 13/13 [==============================] - 1s 43ms/step - loss: 2.
- val_sparse_categorical_accuracy: 0.0000e+00
# Epoch 87/100
# 13/13 [==============================] - 1s 52ms/step - loss: 2.0768 - sparse_categorical_accuracy: 0.1375 - val_loss: 14.4611 - val_sparse_categorical_accuracy: 0.0000e+00
# Epoch 88/100
# 13/13 [==============================] - 1s 48ms/step - loss: 2.0988 - sparse_categorical_accuracy: 0.1075 - val_loss: 14.3262 - val_sparse_categorical_accuracy: 0.0000e+00
# Epoch 89/100
# 13/13 [==============================] - 1s 47ms/step - loss: 2.0845 - sparse_categorical_accuracy: 0.1125 - val_loss: 14.6247 - val_sparse_categorical_accuracy: 0.0000e+00
# Epoch 90/100
# 13/13 [==============================] - 1s 48ms/step - loss: 2.0920 - sparse_categorical_accuracy: 0.0950 - val_loss: 14.5381 - val_sparse_categorical_accuracy: 0.0000e+00
# Epoch 91/100
# 13/13 [==============================] - 1s 52ms/step - loss: 2.0804 - sparse_categorical_accuracy: 0.1400 - val_loss: 14.9391 - val_sparse_categorical_accuracy: 0.0000e+00
# Epoch 92/100
# 13/13 [==============================] - 1s 47ms/step - loss: 2.0953 - sparse_categorical_accuracy: 0.1025 - val_loss: 14.7067 - val_sparse_categorical_accuracy: 0.0000e+00
# Epoch 93/100
# 13/13 [==============================] - 1s 48ms/step - loss: 2.0893 - sparse_categorical_accuracy: 0.1250 - val_loss: 14.4538 - val_sparse_categorical_accuracy: 0.0000e+00
# Epoch 94/100
# 13/13 [==============================] - 1s 47ms/step - loss: 2.0871 - sparse_categorical_accuracy: 0.1150 - val_loss: 14.6410 - val_sparse_categorical_accuracy: 0.0000e+00
# Epoch 95/100
# 13/13 [==============================] - 1s 53ms/step - loss: 2.0891 - sparse_categorical_accuracy: 0.1200 - val_loss: 14.6749 - val_sparse_categorical_accuracy: 0.0000e+00
# Epoch 96/100
# 13/13 [==============================] - 1s 50ms/step - loss: 2.0863 - sparse_categorical_accuracy: 0.1400 - val_loss: 15.1926 - val_sparse_categorical_accuracy: 0.0000e+00
# Epoch 97/100
# 13/13 [==============================] - 1s 48ms/step - loss: 2.0906 - sparse_categorical_accuracy: 0.1100 - val_loss: 15.2351 - val_sparse_categorical_accuracy: 0.0000e+00
# Epoch 98/100
# 13/13 [==============================] - 1s 50ms/step - loss: 2.0864 - sparse_categorical_accuracy: 0.1150 - val_loss: 14.9352 - val_sparse_categorical_accuracy: 0.0000e+00
# Epoch 99/100
# 13/13 [==============================] - 1s 51ms/step - loss: 2.0892 - sparse_categorical_accuracy: 0.1275 - val_loss: 14.6276 - val_sparse_categorical_accuracy: 0.0000e+00
# Epoch 100/100
# 13/13 [==============================] - 1s 46ms/step - loss: 2.0877 - sparse_categorical_accuracy: 0.1425 - val_loss: 14.6381 - val_sparse_categorical_accuracy: 0.0000e+00
# 157/157 [==============================] - 2s 10ms/step - loss: 4.5916 - sparse_categorical_accuracy: 0.1000
# Done! Test-loss: 4.591639995574951 ; Test-acc 0.10000000149011612 ;
# Starting trial with the following parameters :
#  {'actifuns': ['mish', 'mish', 'mish', 'mish', 'mish', 'mish'], 'layer_sizes': [1024, 512, 256, 64, 64, 64], 'batch_size': 50, 'convos': [{'type': 'conv2d', 'value': {'filters': 64, 'kernel_size': (8, 8), 'activation': 'relu', 'padding': 'same'}}, {'type': 'conv2d', 'value': {'filters': 128, 'kernel_size': (8, 8), 'activation': 'relu', 'padding': 'same'}}, {'type': 'conv2d', 'value': {'filters': 128, 'kernel_size': (8, 8), 'activation': 'relu', 'padding': 'same'}}, {'type': 'maxpool', 'value': {'pool_size': (8, 8)}}]}
# Input shape : (500, 128, 96) ; flatten :  False ; do_conv : True
# Input shape : (500, 128, 96, 1)
# Adding layer 0 with size  1024 and activation mish
# Adding layer 1 with size  512 and activation mish
# Adding layer 2 with size  256 and activation mish
# Adding layer 3 with size  64 and activation mish
# Adding layer 4 with size  64 and activation mish
# Adding layer 5 with size  64 and activation mish
# Epoch 1/100
#  8/13 [=================>............] - ETA: 1:22 - loss: 44500.6875 - sparse_categorical_accuracy: 0.0898

# %%
print(model.summary())

# %%
print(test_loss)
print(test_acc)

# %%
print('Result accuracy:',test_acc*10)
